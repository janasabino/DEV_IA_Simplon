# %% [markdown]
# # Projet 2: Compter les mots dans une chaîne
#
# - Compte le nombre de mots individuels dans une chaîne. Pour plus de complexité lire
# ces chaînes à partir d'un fichier texte et générer un summary.

# %%
from collections import Counter
import re

#ouverture et lecture du fichier
texte = open("soleil.txt")
read_texte = texte.read()

#netoyage et passage in minuscule pour ne pas différencier les mêmes mots capitalisés 
mots_lower = read_texte.lower()
mots = mots_lower.split()

#nettoyage des mots: suppression des caracteres non alpha
count_words = []
for words in mots:
    clean_words = re.sub(r'[\W\d_]+', '', words) 
    count_words.append(clean_words)
    good_words = list(filter(None, good_words))
    

#nombre total de mots dans la liste
print("Nombre total de mots dans la liste: ", len(good_words), "\n")

# nombre de chaque mot unique dans la liste
print("Nombre des mots uniques dans la liste: ", Counter(good_words), "\n")

#Summary
print(*good_words, sep='\n')
# Out:
# Nombre total de mots dans la liste:  336
#
# ...
