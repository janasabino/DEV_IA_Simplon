# %%
import re

import numpy as np

import pandas as pd

import spacy

from sentence_transformers import SentenceTransformer

from sklearn.metrics.pairwise import cosine_similarity

# %%
def clean_text(text):
    """
    Nettoyage du dataset: text en miniscule, suppression des chiffres et de tout caractere autre que les lettres
    """

    text = text.lower()

    text = re.sub(r'\d+', '', text)
    
    return " ".join(re.split('\W+', text))

#pour la lemmatisation et stopwords
#le dataset lemmatisé ou pas / stopwords ou pas ne change pas le résultat
nlp = spacy.load("en_core_web_sm") #en_core_web_trf

# %% [markdown]
# Pour le choix de la vectorizaction: [Sentence Transformer](https://www.sbert.net/)
# Il s'agit de vectorizer le text avec la tecnique appellée Word Embedding
# Une description du modèle choisi se trouve [ici](https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2)

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")

def embedded_text(df, text):

    #Créaction d'un array dans la colonne vectorizée
    embed_mat = np.array([x for x in df["embedded"]])

    #vectorisation de l'input - le film qui l'utilisateur tapera
    embedding = model.encode(text)
    
    #Créer l'embedding pour l'input et le répliquer le le nombre de fois la taille du dataset
    m = np.array([embedding]) * len(df)
    
    #calculer la distance entre les vecteurs de l'input et de chaque ligne du dataset
    sim_mat = cosine_similarity(m, embed_mat)

    #créer une collone pour afficher les similarités
    df['sim_score'] = sim_mat[0]

    #afficher les résultats par ordre décroissant
    similarity_results = df.sort_values('sim_score', ascending = False)

    return similarity_results

# %%
df = pd.read_csv("all_movies.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                               cast  \
# 0           0                      ["Charles Kayser","John Ott"]
# 1           1  ["A.C. Abadie","Gilbert M. 'Broncho Billy' And...
# 2           2  ["Martin Fuller","Mrs. William Bechtel","Walte...
# 3           3  ["Frank Powell","Grace Henderson","James Kirkw...
# 4           4                                   ["Winsor McCay"]
#
#                                directors  \
# 0               ["William K.L. Dickson"]
# 1                    ["Edwin S. Porter"]
# 2                     ["Harold M. Shaw"]
# 3                      ["D.W. Griffith"]
# 4  ["Winsor McCay","J. Stuart Blackton"]
#
#                                             fullplot  \
# 0  A stationary camera looks at a large anvil wit...
# 1  Among the earliest existing films in American ...
# 2  Thanks to the Fresh Air Fund, a slum child esc...
# 3  A greedy tycoon decides, on a whim, to corner ...
# 4  Cartoonist Winsor McCay agrees to create a lar...
#
#                                           fullplot.1  \
# 0  A stationary camera looks at a large anvil wit...
# 1  Among the earliest existing films in American ...
# 2  Thanks to the Fresh Air Fund, a slum child esc...
# 3  A greedy tycoon decides, on a whim, to corner ...
# 4  Cartoonist Winsor McCay agrees to create a lar...
#
#                            genres  \
# 0                       ["Short"]
# 1             ["Short","Western"]
# 2     ["Short","Drama","Fantasy"]
# 3               ["Short","Drama"]
# 4  ["Animation","Short","Comedy"]
#
#                                                title  \
# 0                                   Blacksmith Scene
# 1                            The Great Train Robbery
# 2                         The Land Beyond the Sunset
# 3                                  A Corner in Wheat
# 4  Winsor McCay, the Famous Cartoonist of the N.Y...
#
#                                                 plot
# 0  Three men hammer on an anvil and pass a bottle...
# 1  A group of bandits stage a brazen train hold-u...
# 2  A young boy, opressed by his mother, goes on a...
# 3  A greedy tycoon decides, on a whim, to corner ...
# 4  Cartoon figures announce, via comic strip ball...

# %%
df = df[["cast","directors","fullplot","genres","title","plot"]]

# %%
df.head()
# Out:
#                                                 cast  \
# 0                      ["Charles Kayser","John Ott"]
# 1  ["A.C. Abadie","Gilbert M. 'Broncho Billy' And...
# 2  ["Martin Fuller","Mrs. William Bechtel","Walte...
# 3  ["Frank Powell","Grace Henderson","James Kirkw...
# 4                                   ["Winsor McCay"]
#
#                                directors  \
# 0               ["William K.L. Dickson"]
# 1                    ["Edwin S. Porter"]
# 2                     ["Harold M. Shaw"]
# 3                      ["D.W. Griffith"]
# 4  ["Winsor McCay","J. Stuart Blackton"]
#
#                                             fullplot  \
# 0  A stationary camera looks at a large anvil wit...
# 1  Among the earliest existing films in American ...
# 2  Thanks to the Fresh Air Fund, a slum child esc...
# 3  A greedy tycoon decides, on a whim, to corner ...
# 4  Cartoonist Winsor McCay agrees to create a lar...
#
#                            genres  \
# 0                       ["Short"]
# 1             ["Short","Western"]
# 2     ["Short","Drama","Fantasy"]
# 3               ["Short","Drama"]
# 4  ["Animation","Short","Comedy"]
#
#                                                title  \
# 0                                   Blacksmith Scene
# 1                            The Great Train Robbery
# 2                         The Land Beyond the Sunset
# 3                                  A Corner in Wheat
# 4  Winsor McCay, the Famous Cartoonist of the N.Y...
#
#                                                 plot
# 0  Three men hammer on an anvil and pass a bottle...
# 1  A group of bandits stage a brazen train hold-u...
# 2  A young boy, opressed by his mother, goes on a...
# 3  A greedy tycoon decides, on a whim, to corner ...
# 4  Cartoon figures announce, via comic strip ball...

# %%
#remove Nan
df = df.dropna()

# %%
df["text"] = df["cast"] + df["directors"] + df["fullplot"] +df["genres"] + df["title"] + df["plot"]

# %%
#appliquer le nettoyage du texte
df["text_clean"] = df["text"].apply(lambda row: clean_text(row))

# %%
df.head()
# Out:
#                                                 cast  \
# 0                      ["Charles Kayser","John Ott"]
# 1  ["A.C. Abadie","Gilbert M. 'Broncho Billy' And...
# 2  ["Martin Fuller","Mrs. William Bechtel","Walte...
# 3  ["Frank Powell","Grace Henderson","James Kirkw...
# 4                                   ["Winsor McCay"]
#
#                                directors  \
# 0               ["William K.L. Dickson"]
# 1                    ["Edwin S. Porter"]
# 2                     ["Harold M. Shaw"]
# 3                      ["D.W. Griffith"]
# 4  ["Winsor McCay","J. Stuart Blackton"]
#
#                                             fullplot  \
# 0  A stationary camera looks at a large anvil wit...
# 1  Among the earliest existing films in American ...
# 2  Thanks to the Fresh Air Fund, a slum child esc...
# 3  A greedy tycoon decides, on a whim, to corner ...
# 4  Cartoonist Winsor McCay agrees to create a lar...
#
#                            genres  \
# 0                       ["Short"]
# 1             ["Short","Western"]
# 2     ["Short","Drama","Fantasy"]
# 3               ["Short","Drama"]
# 4  ["Animation","Short","Comedy"]
#
#                                                title  \
# 0                                   Blacksmith Scene
# 1                            The Great Train Robbery
# 2                         The Land Beyond the Sunset
# 3                                  A Corner in Wheat
# 4  Winsor McCay, the Famous Cartoonist of the N.Y...
#
#                                                 plot  \
# 0  Three men hammer on an anvil and pass a bottle...
# 1  A group of bandits stage a brazen train hold-u...
# 2  A young boy, opressed by his mother, goes on a...
# 3  A greedy tycoon decides, on a whim, to corner ...
# 4  Cartoon figures announce, via comic strip ball...
#
#                                                 text  \
# 0  ["Charles Kayser","John Ott"]["William K.L. Di...
# 1  ["A.C. Abadie","Gilbert M. 'Broncho Billy' And...
# 2  ["Martin Fuller","Mrs. William Bechtel","Walte...
# 3  ["Frank Powell","Grace Henderson","James Kirkw...
# 4  ["Winsor McCay"]["Winsor McCay","J. Stuart Bla...
#
#                                           text_clean
# 0   charles kayser john ott william k l dickson a...
# 1   a c abadie gilbert m broncho billy anderson g...
# 2   martin fuller mrs william bechtel walter edwi...
# 3   frank powell grace henderson james kirkwood l...
# 4   winsor mccay winsor mccay j stuart blackton c...

# %%
#appliquer le nettoyage du texte
df["text_clean"] = df["text"].apply(lambda row: clean_text(row))

# %%
#créer l'embedding 
df["embedded"] = df["text_clean"].apply(lambda row: model.encode(row))

# %%
#export le dataset embedded (car l'embedding prend assez de temps)
df.to_csv("movies_embedded.csv")

# %% [markdown]
# **Tests**

# %%
test = embedded_text(df, "The Godfather")

# %%
res = test[["title","plot","sim_score"]]

# %%
res.head(15)
# Out:
#                                               title  \
# 2828                                  The Godfather
# 5771                        The Godfather: Part III
# 3055                         The Godfather: Part II
# 17826  I Knew It Was You: Rediscovering John Cazale
# 8310                           Jane Austen's Mafia!
# 2343                                The Brotherhood
# 17333                                    Neon Flesh
# 13267                                       C(r)ook
# 5762                                   The Freshman
# 3189                                  The Passenger
# 5826                              Miller's Crossing
# 17726                                 Kiss Me Again
# 11253            Before the Devil Knows You're Dead
# 7999                                        Hoodlum
# 7939                                  Donnie Brasco
#
#                                                     plot  sim_score
# 2828   The aging patriarch of an organized crime dyna...   0.667662
# 5771   In the midst of trying to legitimize his busin...   0.647936
# 3055   The early life and career of Vito Corleone in ...   0.614185
# 17826  A portrait of the acting craft of John Cazale ...   0.605067
# 8310   Takeoff on the Godfather with the son of a maf...   0.527654
# 2343   The son of a powerful Mafia don comes home fro...   0.519522
# 17333  Hoping to earn his mother's respect, a young h...   0.517793
# 13267  A killer for the Russian Mafia in Vienna wants...   0.509353
# 5762   Clark Kellogg is a young man starting his firs...   0.501665
# 3189   A frustrated war correspondent, unable to find...   0.500335
# 5826   Tom Regan, an advisor to a Prohibition-era cri...   0.488000
# 17726  A look at the lives of Carlo, Giulia, and thei...   0.484727
# 11253  When two brothers organize the robbery of thei...   0.482343
# 7999   Black gangsters in 1930 Harlem fights Dutch Sc...   0.475168
# 7939   An FBI undercover agent infiltrates the mob an...   0.472779
